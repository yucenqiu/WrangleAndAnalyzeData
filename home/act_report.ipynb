# %% [markdown]
# # WeRateDogs Data Insight

# %% [markdown]
# The follower insights are listed in the same order as the charts that were displayed in the wrangle_acts.ipynb file

# %% [markdown]
# 1. The first graph is a pie chart displaying the distribution of the 4 life stages of dog: doggo, floofer, puppo, pupper. We can see from this chart that all four life stages of dogs are equally distributed among the tweets.

# %% [markdown]
# 2. The second visualization is a bar graph that helps us understand popular dog names among dog owners through the WeRateDogs tweets. Through this graph we can see that Charlie is by far the most popular dog name at 60 count and Sadie is at number 10 with 40 counts.

# %% [markdown]
# 3. The last graph serves to help us better understand how is the number of favorites are correlated with the number of retweets. Through this graph we can see that there exist a positive correlation between favorites and retweets.
